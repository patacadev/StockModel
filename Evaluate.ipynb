# %%
from src.data.make_dataset import load_list, get_stock_data
from src.models.StockModel import StockModel
window_size = 20
start_date = '2017-01-01'
end_date = '2024-09-01'
feature_columns = ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
target = "Open"

# Test data
test_data = get_stock_data(["^GSPC", "^DJI"], "1d", start_date, end_date)

stock_model = StockModel(window_size=window_size, feature_columns=feature_columns, target_name=target, export=False)
stock_model.load("final_models/1-64")

metrics_dict, mean_metrics = stock_model.evaluate_many(test_data, graph=True)
print(metrics_dict)
print(mean_metrics)
# Out:
# Initializing model:
#  - Window size: 20
#  - Features: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
#  - Target: Open
# Saving model from final_models/1-64...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          18,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,261 (219.77 KB)
#  Trainable params: 18,753 (73.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,508 (146.52 KB)
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 2.23739990e+03  2.26160010e+03  1.29653000e+09  3.79003906e+00
#  -2.02429932e+02  4.00986440e+00 -2.37020227e+02 -6.12211011e+01]
# Feature max [5.66720020e+03 5.64408984e+03 9.97652000e+09 2.18959961e+02
#  1.11319824e+02 1.00000000e+02 9.25837114e+01 6.08958036e+01]
# Target min [2251.57006836]
# Target max [5644.08984375]
# Predict with X shape: (1907, 20, 8)
# Target min [2251.57006836]
# Target max [5644.08984375]
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Loss: 72.9417 MAPE: 0.1783 R2: 0.9999
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 1.85919297e+04  1.90283594e+04  8.61500000e+07  3.91796875e+01
#  -2.26808984e+03  7.28670712e+00 -2.30588627e+03 -5.56506467e+02]
# Feature max [4.15630781e+04 4.13661602e+04 9.15990000e+08 1.90439062e+03
#  1.14450000e+03 1.00000000e+02 8.63814100e+02 5.36040164e+02]
# Target min [19028.359375]
# Target max [41366.16015625]
# Predict with X shape: (1907, 20, 8)
# Target min [19028.359375]
# Target max [41366.16015625]
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 17256.3138 MAPE: 0.4299 R2: 0.9994
# {'^GSPC': {'loss': 72.94170183827876, 'mape': 0.17830758142925857, 'r2': 0.9999053163558401}, '^DJI': {'loss': 17256.313797493163, 'mape': 0.4299357190709717, 'r2': 0.999405068124287}}
# {'mean': {'loss': 8664.62774966572, 'mape': 0.30412165025011517, 'r2': 0.9996551922400636}, 'median': {'loss': 8664.62774966572, 'mape': 0.30412165025011517, 'r2': 0.9996551922400636}, 'number_tickers': 2}

# %%
from src.data.make_dataset import load_list, get_stock_data
from src.models.StockModel import StockModel
window_size = 20
start_date = '2020-01-01'
end_date = '2020-09-01'
feature_columns = ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
target = "Open"

# Test data
test_data = get_stock_data(["^GSPC", "^DJI"], "1d", start_date, end_date)

stock_model = StockModel(window_size=window_size, feature_columns=feature_columns, target_name=target, export=False)
stock_model.load("final_models/1-64")

metrics_dict, mean_metrics = stock_model.evaluate_many(test_data, graph=True)
print(metrics_dict)
print(mean_metrics)
# Out:
# Initializing model:
#  - Window size: 20
#  - Features: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
#  - Target: Open
# Saving model from final_models/1-64...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          18,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,261 (219.77 KB)
#  Trainable params: 18,753 (73.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,508 (146.52 KB)
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 2.23739990e+03  2.29070996e+03  3.20006000e+09  8.37011719e+00
#  -2.02429932e+02  0.00000000e+00 -2.38129990e+02 -6.04753981e+01]
# Feature max [3.50801001e+03 3.50972998e+03 9.05395000e+09 2.18959961e+02
#  1.07040039e+02 8.67198967e+01 9.06868726e+01 6.10601600e+01]
# Target min [2290.70996094]
# Target max [3509.72998047]
# Predict with X shape: (147, 20, 8)
# Target min [2290.70996094]
# Target max [3509.72998047]
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Loss: 186.3144 MAPE: 0.3908 R2: 0.9977
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 1.85919297e+04  1.90283594e+04  2.31000000e+08  8.37089844e+01
#  -2.26808984e+03  0.00000000e+00 -2.31511798e+03 -5.50330434e+02]
# Feature max [2.95514199e+04 2.94404707e+04 9.15990000e+08 1.90439062e+03
#  1.13025977e+03 8.63417571e+01 8.63679566e+02 5.37632534e+02]
# Target min [19028.359375]
# Target max [29440.47070312]
# Predict with X shape: (147, 20, 8)
# Target min [19028.359375]
# Target max [29440.47070312]
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 12107.5691 MAPE: 0.3613 R2: 0.9979
# {'^GSPC': {'loss': 186.31435079680014, 'mape': 0.3908443980832146, 'r2': 0.9976652756365053}, '^DJI': {'loss': 12107.569083388958, 'mape': 0.3612863893506876, 'r2': 0.997878462544889}}
# {'mean': {'loss': 6146.941717092879, 'mape': 0.3760653937169511, 'r2': 0.9977718690906971}, 'median': {'loss': 6146.941717092879, 'mape': 0.3760653937169511, 'r2': 0.9977718690906971}, 'number_tickers': 2}

# %%
from src.data.make_dataset import load_list, get_stock_data
from src.models.StockModel import StockModel
window_size = 20
start_date = '2022-01-01'
end_date = '2023-01-01'
feature_columns = ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
target = "Open"

# Test data
test_data = get_stock_data(["^GSPC", "^DJI"], "1d", start_date, end_date)

stock_model = StockModel(window_size=window_size, feature_columns=feature_columns, target_name=target, export=False)
stock_model.load("final_models/1-64")

metrics_dict, mean_metrics = stock_model.evaluate_many(test_data, graph=True)
print(metrics_dict)
print(mean_metrics)
# Out:
# Initializing model:
#  - Window size: 20
#  - Features: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
#  - Target: Open
# Saving model from final_models/1-64...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          18,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,261 (219.77 KB)
#  Trainable params: 18,753 (73.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,508 (146.52 KB)
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 3.57703003e+03  3.52037012e+03  1.70646000e+09  1.32600098e+01
#  -7.32900391e+01  0.00000000e+00 -1.16456264e+02 -4.08065888e+01]
# Feature max [4.79354004e+03 4.80450977e+03 8.52074000e+09 1.94729980e+02
#  1.11319824e+02 8.57751648e+01 9.25830609e+01 3.92742478e+01]
# Target min [3520.37011719]
# Target max [4804.50976562]
# Predict with X shape: (230, 20, 8)
# Target min [3520.37011719]
# Target max [4804.50976562]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Loss: 429.6744 MAPE: 0.4369 R2: 0.9938
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 2.87255098e+04  2.87558301e+04  1.31660000e+08  1.65839844e+02
#  -4.55019531e+02  1.01995086e+01 -8.32377975e+02 -2.92438597e+02]
# Feature max [3.67996484e+04 3.67226016e+04 7.56310000e+08 1.50759961e+03
#  7.49970703e+02 1.00000000e+02 7.59483373e+02 3.61432984e+02]
# Target min [28755.83007812]
# Target max [36722.6015625]
# Predict with X shape: (230, 20, 8)
# Target min [28755.83007812]
# Target max [36722.6015625]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 6393.0528 MAPE: 0.1936 R2: 0.9975
# {'^GSPC': {'loss': 429.67439689299385, 'mape': 0.4369317125589446, 'r2': 0.993789640547076}, '^DJI': {'loss': 6393.05275625147, 'mape': 0.19357495568144337, 'r2': 0.9975156781919388}}
# {'mean': {'loss': 3411.363576572232, 'mape': 0.31525333412019396, 'r2': 0.9956526593695074}, 'median': {'loss': 3411.363576572232, 'mape': 0.31525333412019396, 'r2': 0.9956526593695074}, 'number_tickers': 2}

# %%
from src.data.make_dataset import load_list, get_stock_data
from src.models.StockModel import StockModel
window_size = 20
start_date = '2021-01-01'
end_date = '2022-01-01'
feature_columns = ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
target = "Open"

# Test data
test_data = get_stock_data(["^GSPC", "^DJI"], "1d", start_date, end_date)

stock_model = StockModel(window_size=window_size, feature_columns=feature_columns, target_name=target, export=False)
stock_model.load("final_models/1-64")

metrics_dict, mean_metrics = stock_model.evaluate_many(test_data, graph=True)
print(metrics_dict)
print(mean_metrics)
# Out:
# Initializing model:
#  - Window size: 20
#  - Features: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD']
#  - Target: Open
# Saving model from final_models/1-64...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          18,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,261 (219.77 KB)
#  Trainable params: 18,753 (73.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,508 (146.52 KB)
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 3.71423999e+03  3.69802002e+03  2.67782000e+09  7.55029297e+00
#  -3.80903320e+01  2.10264799e+01 -3.30348734e+01 -2.53251400e+01]
# Feature max [4.79306006e+03 4.79549023e+03 9.97652000e+09 1.42669922e+02
#  4.03002930e+01 1.00000000e+02 6.86488314e+01 2.34635544e+01]
# Target min [3698.02001953]
# Target max [4795.49023438]
# Predict with X shape: (231, 20, 8)
# Target min [3698.02001953]
# Target max [4795.49023438]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Loss: 30.1115 MAPE: 0.0936 R2: 0.9996
# Feature columns: ['Close', 'Open', 'Volume', 'Range', 'Gap', 'RSI', 'MACD', 'MACD_Hist']
# Target column: Open
# Feature min [ 2.99826191e+04  3.00547305e+04  2.05620000e+08  8.92890625e+01
#  -4.37687500e+02  1.56656415e+01 -2.78074607e+02 -2.37948792e+02]
# Feature max [3.64886289e+04 3.65224805e+04 8.11890000e+08 9.97660156e+02
#  1.96957031e+02 1.00000000e+02 4.82757152e+02 1.54555351e+02]
# Target min [30054.73046875]
# Target max [36522.48046875]
# Predict with X shape: (231, 20, 8)
# Target min [30054.73046875]
# Target max [36522.48046875]
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Loss: 2510.5994 MAPE: 0.1208 R2: 0.9986
# {'^GSPC': {'loss': 30.111465913134758, 'mape': 0.09355875889235887, 'r2': 0.999551890097515}, '^DJI': {'loss': 2510.5994125960565, 'mape': 0.12079503645259342, 'r2': 0.9986486388215808}}
# {'mean': {'loss': 1270.3554392545957, 'mape': 0.10717689767247615, 'r2': 0.9991002644595479}, 'median': {'loss': 1270.3554392545957, 'mape': 0.10717689767247615, 'r2': 0.9991002644595479}, 'number_tickers': 2}
